# %%
pip install --upgrade transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers in c:\users\eshwar prasad\appdata\roaming\python\python39\site-packages (4.40.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\eshwar prasad\appdata\roaming\python\python39\site-packages (from transformers) (1.22.4)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\eshwar prasad\appdata\roaming\python\python39\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\lib\site-packages (from transformers) (3.6.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\programdata\anaconda3\lib\site-packages (from transformers) (2022.3.15)
# Requirement already satisfied: tqdm>=4.27 in c:\programdata\anaconda3\lib\site-packages (from transformers) (4.64.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in c:\users\eshwar prasad\appdata\roaming\python\python39\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\eshwar prasad\appdata\roaming\python\python39\site-packages (from transformers) (0.19.1)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from transformers) (2.27.1)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\eshwar prasad\appdata\roaming\python\python39\site-packages (from transformers) (0.4.3)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from transformers) (21.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.1.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\eshwar prasad\appdata\roaming\python\python39\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2024.3.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging>=20.0->transformers) (3.0.4)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\eshwar prasad\appdata\roaming\python\python39\site-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->transformers) (1.26.9)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\eshwar prasad\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\eshwar prasad\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\eshwar prasad\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\eshwar prasad\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\eshwar prasad\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\eshwar prasad\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\eshwar prasad\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\eshwar prasad\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\eshwar prasad\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\eshwar prasad\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\eshwar prasad\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\eshwar prasad\appdata\roaming\python\python39\site-packages)

# %%
from transformers import AutoTokenizer, AutoModelForQuestionAnswering, TrainingArguments, Trainer
from fitz import open  # PyMuPDF library
from tqdm import tqdm  # Progress bar library
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python39\site-packages\transformers\utils\import_utils.py:1510, in _LazyModule._get_module(self, module_name)
#    1509 try:
# -> 1510     return importlib.import_module("." + module_name, self.__name__)
#    1511 except Exception as e:
#
# File C:\ProgramData\Anaconda3\lib\importlib\__init__.py:127, in import_module(name, package)
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:986, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:680, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:850, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\transformers\trainer.py:59, in <module>
#      58 from .configuration_utils import PretrainedConfig
# ---> 59 from .data.data_collator import DataCollator, DataCollatorWithPadding, default_data_collator
#      60 from .debug_utils import DebugOption, DebugUnderflowOverflow
#
# File ~\AppData\Roaming\Python\Python39\site-packages\transformers\data\__init__.py:27, in <module>
#      26 from .metrics import glue_compute_metrics, xnli_compute_metrics
# ---> 27 from .processors import (
#      28     DataProcessor,
#      29     InputExample,
#      30     InputFeatures,
#      31     SingleSentenceClassificationProcessor,
#      32     SquadExample,
#      33     SquadFeatures,
#      34     SquadV1Processor,
#      35     SquadV2Processor,
#      36     glue_convert_examples_to_features,
#      37     glue_output_modes,
#      38     glue_processors,
#      39     glue_tasks_num_labels,
#      40     squad_convert_examples_to_features,
#      41     xnli_output_modes,
#      42     xnli_processors,
#      43     xnli_tasks_num_labels,
#      44 )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\transformers\data\processors\__init__.py:15, in <module>
#       1 # Copyright 2020 The HuggingFace Team. All rights reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
# ---> 15 from .glue import glue_convert_examples_to_features, glue_output_modes, glue_processors, glue_tasks_num_labels
#      16 from .squad import SquadExample, SquadFeatures, SquadV1Processor, SquadV2Processor, squad_convert_examples_to_features
#
# File ~\AppData\Roaming\Python\Python39\site-packages\transformers\data\processors\glue.py:30, in <module>
#      29 if is_tf_available():
# ---> 30     import tensorflow as tf
#      32 logger = logging.get_logger(__name__)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\__init__.py:52, in <module>
#      51 from ._api.v2 import bitwise
# ---> 52 from ._api.v2 import compat
#      53 from ._api.v2 import config
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\_api\v2\compat\__init__.py:37, in <module>
#      35 import sys as _sys
# ---> 37 from . import v1
#      38 from . import v2
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\_api\v2\compat\v1\__init__.py:31, in <module>
#      30 from . import bitwise
# ---> 31 from . import compat
#      32 from . import config
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\_api\v2\compat\v1\compat\__init__.py:38, in <module>
#      37 from . import v1
# ---> 38 from . import v2
#      39 from tensorflow.python.compat.compat import forward_compatibility_horizon
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\_api\v2\compat\v1\compat\v2\__init__.py:28, in <module>
#      27 from . import compat
# ---> 28 from tensorflow._api.v2.compat.v2 import __internal__
#      29 from tensorflow._api.v2.compat.v2 import __operators__
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\_api\v2\compat\v2\__init__.py:33, in <module>
#      32 from . import bitwise
# ---> 33 from . import compat
#      34 from . import config
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\_api\v2\compat\v2\compat\__init__.py:38, in <module>
#      37 from . import v1
# ---> 38 from . import v2
#      39 from tensorflow.python.compat.compat import forward_compatibility_horizon
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\_api\v2\compat\v2\compat\v2\__init__.py:334, in <module>
#     333 try:
# --> 334   from tensorboard.summary._tf import summary
#     335   _current_module.__path__ = (
#     336       [_module_util.get_parent_dir(summary)] + _current_module.__path__)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorboard\summary\__init__.py:22, in <module>
#      21 try:
# ---> 22     from tensorboard.summary import v1  # noqa: F401
#      23 except ImportError:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorboard\summary\v1.py:23, in <module>
#      22 from tensorboard.plugins.custom_scalar import summary as _custom_scalar_summary
# ---> 23 from tensorboard.plugins.histogram import summary as _histogram_summary
#      24 from tensorboard.plugins.image import summary as _image_summary
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorboard\plugins\histogram\summary.py:35, in <module>
#      34 from tensorboard.plugins.histogram import metadata
# ---> 35 from tensorboard.plugins.histogram import summary_v2
#      38 # Export V3 versions.
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorboard\plugins\histogram\summary_v2.py:35, in <module>
#      34 from tensorboard.util import lazy_tensor_creator
# ---> 35 from tensorboard.util import tensor_util
#      38 DEFAULT_BUCKET_COUNT = 30
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorboard\util\tensor_util.py:20, in <module>
#      19 from tensorboard.compat.proto import tensor_pb2
# ---> 20 from tensorboard.compat.tensorflow_stub import dtypes, compat, tensor_shape
#      23 def ExtractBitsFromFloat16(x):
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorboard\compat\tensorflow_stub\__init__.py:22, in <module>
#      21 from tensorboard.compat.proto.summary_pb2 import *  # noqa
# ---> 22 from .dtypes import as_dtype  # noqa
#      23 from .dtypes import DType  # noqa
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:19, in <module>
#      17 import numpy as np
# ---> 19 from . import pywrap_tensorflow
#      20 from tensorboard.compat.proto import types_pb2
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorboard\compat\tensorflow_stub\pywrap_tensorflow.py:22, in <module>
#      21 from . import errors
# ---> 22 from .io import gfile
#      25 TFE_DEVICE_PLACEMENT_WARN = 0
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorboard\compat\tensorflow_stub\io\__init__.py:17, in <module>
#       1 # Copyright 2018 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
# ---> 17 from . import gfile
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorboard\compat\tensorflow_stub\io\gfile.py:33, in <module>
#      32 import botocore.exceptions
# ---> 33 import boto3
#      35 S3_ENABLED = True
#
# File C:\ProgramData\Anaconda3\lib\site-packages\boto3\__init__.py:17, in <module>
#      16 from boto3.compat import _warn_deprecated_python
# ---> 17 from boto3.session import Session
#      19 __author__ = 'Amazon Web Services'
#
# File C:\ProgramData\Anaconda3\lib\site-packages\boto3\session.py:17, in <module>
#      15 import os
# ---> 17 import botocore.session
#      18 from botocore.client import Config
#
# File C:\ProgramData\Anaconda3\lib\site-packages\botocore\session.py:26, in <module>
#      24 import warnings
# ---> 26 import botocore.client
#      27 import botocore.configloader
#
# File C:\ProgramData\Anaconda3\lib\site-packages\botocore\client.py:15, in <module>
#      13 import logging
# ---> 15 from botocore import waiter, xform_name
#      16 from botocore.args import ClientArgsCreator
#
# File C:\ProgramData\Anaconda3\lib\site-packages\botocore\waiter.py:18, in <module>
#      16 import jmespath
# ---> 18 from botocore.docs.docstring import WaiterDocstring
#      19 from botocore.utils import get_service_module_name
#
# File C:\ProgramData\Anaconda3\lib\site-packages\botocore\docs\__init__.py:15, in <module>
#      13 import os
# ---> 15 from botocore.docs.service import ServiceDocumenter
#      18 def generate_docs(root_dir, session):
#
# File C:\ProgramData\Anaconda3\lib\site-packages\botocore\docs\service.py:14, in <module>
#      13 from botocore.docs.bcdoc.restdoc import DocumentStructure
# ---> 14 from botocore.docs.client import ClientDocumenter, ClientExceptionsDocumenter
#      15 from botocore.docs.paginator import PaginatorDocumenter
#
# File C:\ProgramData\Anaconda3\lib\site-packages\botocore\docs\client.py:14, in <module>
#      13 from botocore.compat import OrderedDict
# ---> 14 from botocore.docs.example import ResponseExampleDocumenter
#      15 from botocore.docs.method import (
#      16     document_custom_method,
#      17     document_model_driven_method,
#      18     get_instance_public_methods,
#      19 )
#
# File C:\ProgramData\Anaconda3\lib\site-packages\botocore\docs\example.py:13, in <module>
#       1 # Copyright 2015 Amazon.com, Inc. or its affiliates. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License"). You
#    (...)
#      11 # ANY KIND, either express or implied. See the License for the specific
#      12 # language governing permissions and limitations under the License.
# ---> 13 from botocore.docs.shape import ShapeDocumenter
#      14 from botocore.docs.utils import py_default
#
# File C:\ProgramData\Anaconda3\lib\site-packages\botocore\docs\shape.py:19, in <module>
#       1 # Copyright 2015 Amazon.com, Inc. or its affiliates. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License"). You
#    (...)
#      17 # inherited from a Documenter class with the appropriate methods
#      18 # and attributes.
# ---> 19 from botocore.utils import is_json_value_header
#      22 class ShapeDocumenter(object):
#
# File C:\ProgramData\Anaconda3\lib\site-packages\botocore\utils.py:34, in <module>
#      33 import botocore.awsrequest
# ---> 34 import botocore.httpsession
#      35 from botocore.compat import (
#      36     HAS_CRT,
#      37     MD5_AVAILABLE,
#    (...)
#      47     zip_longest,
#      48 )
#
# File C:\ProgramData\Anaconda3\lib\site-packages\botocore\httpsession.py:34, in <module>
#      32 try:
#      33     # Always import the original SSLContext, even if it has been patched
# ---> 34     from urllib3.contrib.pyopenssl import orig_util_SSLContext as SSLContext
#      35 except ImportError:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py:50, in <module>
#      48 from __future__ import absolute_import
# ---> 50 import OpenSSL.SSL
#      51 from cryptography import x509
#
# File C:\ProgramData\Anaconda3\lib\site-packages\OpenSSL\__init__.py:8, in <module>
#       4 """
#       5 pyOpenSSL - A simple wrapper around the OpenSSL library
#       6 """
# ----> 8 from OpenSSL import crypto, SSL
#       9 from OpenSSL.version import (
#      10     __author__,
#      11     __copyright__,
#    (...)
#      17     __version__,
#      18 )
#
# File C:\ProgramData\Anaconda3\lib\site-packages\OpenSSL\crypto.py:1579, in <module>
#    1576         return ext
# -> 1579 class X509StoreFlags(object):
#    1580     """
#    1581     Flags for X509 verification, used to change the behavior of
#    1582     :class:`X509Store`.
#    (...)
#    1587         https://www.openssl.org/docs/manmaster/man3/X509_VERIFY_PARAM_set_flags.html
#    1588     """
#
# File C:\ProgramData\Anaconda3\lib\site-packages\OpenSSL\crypto.py:1598, in X509StoreFlags()
#    1597 INHIBIT_MAP = _lib.X509_V_FLAG_INHIBIT_MAP
# -> 1598 NOTIFY_POLICY = _lib.X509_V_FLAG_NOTIFY_POLICY
#    1599 CHECK_SS_SIGNATURE = _lib.X509_V_FLAG_CHECK_SS_SIGNATURE
#
# AttributeError: module 'lib' has no attribute 'X509_V_FLAG_NOTIFY_POLICY'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 from transformers import AutoTokenizer, AutoModelForQuestionAnswering, TrainingArguments, Trainer
#       2 from fitz import open  # PyMuPDF library
#       3 from tqdm import tqdm
#
# File <frozen importlib._bootstrap>:1055, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\transformers\utils\import_utils.py:1500, in _LazyModule.__getattr__(self, name)
#    1498     value = self._get_module(name)
#    1499 elif name in self._class_to_module.keys():
# -> 1500     module = self._get_module(self._class_to_module[name])
#    1501     value = getattr(module, name)
#    1502 else:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\transformers\utils\import_utils.py:1512, in _LazyModule._get_module(self, module_name)
#    1510     return importlib.import_module("." + module_name, self.__name__)
#    1511 except Exception as e:
# -> 1512     raise RuntimeError(
#    1513         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1514         f" traceback):\n{e}"
#    1515     ) from e
#
# RuntimeError: Failed to import transformers.trainer because of the following error (look up to see its traceback):
# module 'lib' has no attribute 'X509_V_FLAG_NOTIFY_POLICY'
